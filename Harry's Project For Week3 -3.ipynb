# %%
from bs4 import BeautifulSoup
import requests
import csv
import numpy as np
import pandas as pd

source = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M').text
soup = BeautifulSoup(source, 'lxml')

body = soup.find('tbody').text
body = body.split('\n')

# %%
PostCode=[None]*288
Borough=[None]*288
Neighbourhood=[None]*288

for a in range(288):
    PostCode[a] = body[6+a*5]

for b in range(288):    
    Borough[b] = body[7+b*5]
    
for c in range(288):
    Neighbourhood[c] = body[8+c*5]

csv_file = open('neighborhoods in Toronto.csv','w')     
csv_writer = csv.writer(csv_file)
csv_writer.writerow(['PostCode','Borough','Neighbourhood'])

for i in range(288):
    csv_writer.writerow([PostCode[i],Borough[i],Neighbourhood[i]])

csv_file.close()

# %%
data = pd.read_csv("neighborhoods in Toronto.csv")

for i in range(288):
    if data["Borough"][i]=='Not assigned':
        data["Borough"][i]='0'
        
a=data[(data.Borough=='0')].index.tolist()
data=data.drop(a)
data.reset_index(inplace=True)
data=data.drop(columns=["index"])

# %%
b=[]
for j in range(len(data['PostCode'])-1):
    if data["PostCode"][j] == data["PostCode"][j+1] and data["Neighbourhood"][j] != data["Neighbourhood"][j+1]:
        data["Neighbourhood"][j] = data["Neighbourhood"][j]+','+data["Neighbourhood"][j+1]
        b.append(j+1)
data=data.drop(b)
data.reset_index(inplace=True)
data=data.drop(columns=["index"])

b=[]
for j in range(len(data['PostCode'])-1):
    if data["PostCode"][j] == data["PostCode"][j+1] and data["Neighbourhood"][j] != data["Neighbourhood"][j+1]:
        data["Neighbourhood"][j] = data["Neighbourhood"][j]+','+data["Neighbourhood"][j+1]
        b.append(j+1)
data=data.drop(b)
data.reset_index(inplace=True)
data=data.drop(columns=["index"])

b=[]
for j in range(len(data['PostCode'])-1):
    if data["PostCode"][j] == data["PostCode"][j+1] and data["Neighbourhood"][j] != data["Neighbourhood"][j+1]:
        data["Neighbourhood"][j] = data["Neighbourhood"][j]+','+data["Neighbourhood"][j+1]
        b.append(j+1)
data=data.drop(b)
data.reset_index(inplace=True)
data=data.drop(columns=["index"])

b=[]
for j in range(len(data['PostCode'])-1):
    if data["PostCode"][j] == data["PostCode"][j+1] and data["Neighbourhood"][j] != data["Neighbourhood"][j+1]:
        data["Neighbourhood"][j] = data["Neighbourhood"][j]+','+data["Neighbourhood"][j+1]
        b.append(j+1)
data=data.drop(b)
data.reset_index(inplace=True)
data=data.drop(columns=["index"])

b=[]
for j in range(len(data['PostCode'])-1):
    if data["PostCode"][j] == data["PostCode"][j+1] and data["Neighbourhood"][j] != data["Neighbourhood"][j+1]:
        data["Neighbourhood"][j] = data["Neighbourhood"][j]+','+data["Neighbourhood"][j+1]
        b.append(j+1)
data=data.drop(b)
data.reset_index(inplace=True)
data=data.drop(columns=["index"])

b=[]
for j in range(len(data['PostCode'])-1):
    if data["PostCode"][j] == data["PostCode"][j+1] and data["Neighbourhood"][j] != data["Neighbourhood"][j+1]:
        data["Neighbourhood"][j] = data["Neighbourhood"][j]+','+data["Neighbourhood"][j+1]
        b.append(j+1)
data=data.drop(b)
data.reset_index(inplace=True)
data=data.drop(columns=["index"])

b=[]
for j in range(len(data['PostCode'])-1):
    if data["PostCode"][j] == data["PostCode"][j+1] and data["Neighbourhood"][j] != data["Neighbourhood"][j+1]:
        data["Neighbourhood"][j] = data["Neighbourhood"][j]+','+data["Neighbourhood"][j+1]
        b.append(j+1)
data=data.drop(b)
data.reset_index(inplace=True)
data=data.drop(columns=["index"])

b=[]
for j in range(len(data['PostCode'])-1):
    if data["PostCode"][j] == data["PostCode"][j+1] and data["Neighbourhood"][j] != data["Neighbourhood"][j+1]:
        data["Neighbourhood"][j] = data["Neighbourhood"][j]+','+data["Neighbourhood"][j+1]
        b.append(j+1)
data=data.drop(b)
data.reset_index(inplace=True)
data=data.drop(columns=["index"])

b=[]
for j in range(len(data['PostCode'])-1):
    if data["PostCode"][j] == data["PostCode"][j+1] and data["Neighbourhood"][j] != data["Neighbourhood"][j+1]:
        data["Neighbourhood"][j] = data["Neighbourhood"][j]+','+data["Neighbourhood"][j+1]
        b.append(j+1)
data=data.drop(b)
data.reset_index(inplace=True)
data=data.drop(columns=["index"])

b=[]
for j in range(len(data['PostCode'])-1):
    if data["PostCode"][j] == data["PostCode"][j+1] and data["Neighbourhood"][j] != data["Neighbourhood"][j+1]:
        data["Neighbourhood"][j] = data["Neighbourhood"][j]+','+data["Neighbourhood"][j+1]
        b.append(j+1)
data=data.drop(b)
data.reset_index(inplace=True)
data=data.drop(columns=["index"])

# %%
for k in range(103):
    if data["Neighbourhood"][k]=='Not assigned':
        data["Neighbourhood"][k]=data["Borough"][k]

# %%
# !wget -O Geospatial_data.csv http://cocl.us/Geospatial_data
from pandas import DataFrame

df = DataFrame(data)
data2 = df.sort_values(by='PostCode', ascending=True)
data2.reset_index(inplace=True)
data2 = data2.drop(columns=["index"])
data2 = DataFrame(data2)

geodata = pd.read_csv("Geospatial_data.csv")
df2 = DataFrame(geodata)
geodata2 = df2.sort_values(by='Postal Code', ascending=True)
geodata2.reset_index(inplace=True)
geodata2 = geodata2.drop(columns=["index"])
geodata2 = DataFrame(geodata2)

geodata2 = geodata2.rename(columns={'Postal Code':'PostCode'})
data3 = pd.merge(data2,geodata2)
# Out:
# --2019-04-16 06:40:40--  http://cocl.us/Geospatial_data
# Resolving cocl.us (cocl.us)... 169.48.113.201
# Connecting to cocl.us (cocl.us)|169.48.113.201|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://cocl.us/Geospatial_data [following]
# --2019-04-16 06:40:40--  https://cocl.us/Geospatial_data
# Connecting to cocl.us (cocl.us)|169.48.113.201|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://ibm.box.com/shared/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2019-04-16 06:40:43--  https://ibm.box.com/shared/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Resolving ibm.box.com (ibm.box.com)... 107.152.25.197, 107.152.24.197
# Connecting to ibm.box.com (ibm.box.com)|107.152.25.197|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2019-04-16 06:40:43--  https://ibm.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Reusing existing connection to ibm.box.com:443.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://ibm.ent.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2019-04-16 06:40:43--  https://ibm.ent.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Resolving ibm.ent.box.com (ibm.ent.box.com)... 107.152.26.211
# Connecting to ibm.ent.box.com (ibm.ent.box.com)|107.152.26.211|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://public.boxcloud.com/d/1/b1!dw4qbcIkDnSN0U0uBWTdlBQVSTsQjQAnkq57cdovqB1aeTUZc07TyEPbxCMCQUkHpV0w6zBZY1RREAnZtds5s0t8sUzkppPlWcFYtQgkYwCr_BAA4DH6mRQAov3aK7mAbtuTAFRTPXzPcXM3adV9h2pI6Ki58K3Nn4ftUwEVB5UZXaM8b3IUb3Z-1PTmybIc5qlzsLxLRu3MGeIQdOj_g3QcsYyV3AxA0Iftw_Btj-MidgvoK7R4Vf-7twz4Ra_DQXqapo28DnjJr-zBE0PmwuqFq72B9bB7TPQOT06kU5BxU_qK3hIWYh_r2l6LiqCWJaCHjGR_-scyVrbwuL5pTGVZcuuYpTT88vCVyvleQITVosgetwVeBkfSJz3-6cjA6mTk0D9awcobJpc5uNKGnAntm725zkpZSm2trqWywR6g6wWCxAenM5CAYv0g3XcNXHVYnmTIzVHoAUo41NRgPL4wsNwCNAad79UpwpxKogFVDMQeE_MJEPayLQvXQMhFbgIRVdv2Gz1KPN-_e6Y9rxoDA0DE-svQs7WMvnVqNHrhbtlEKWsjuY4scC7wK0nwF2G4o_WOn-n4Y1oGmgbMNOu1dIgLcQ0q1Bv7QcH8fMko1Z9_uFtEFYahWlt5NEhkAWH-tkTZPPazh7mKVBf4q_X9JsyZeZfci_TbuZ5YOSjFtZ2gdxOx32GL1CxOBWWIBic2vjVv4yeNfCBjW47vJxy2Jgfa1eDE3Luub0FTtPyizEBx2emzk4srtXB8Y2b4bWCrRgcj28jdiQziXhwf54RKFbNsipuavekL6BCE1orwo4N3gtYJamlc5OH_hyHJNMGT-3yrx4fNLmahunfOFYDihGJ0_cDSGgBk_KlIR6_qQQgMD2Oc1VVtRjVhKiRQSnPmXnzg-9hgCksm_oS254d8i29Rq2KSMy6yvA8JNMUH89yIn5KZ-dnRANRw3ToAjcZqNbzcrAZMt01XLpGNOH3JNL2GzXV75x_mA9eR9hskSujf06QPU5U2VWF0MDh9VgaK0j590Q2C63Xt_kwx0UG7ltDhlywl5WvI_dfIC76QcxSfO7an6eVDy7guGPehShB4tg5ihst5ItWvMu0PA9J0JHA-NSDOTWRC-dXCa6OKGgqXxfoBLCjXirTbGem8KdNfzLGNTwbINgCr4MfS9wDwocn93-bO1K590LfTlrquqcKilYIClxoql97J3Pgp0k2er4mNqyTjeaP6BK3tZRYj94PRRPR1ULjADnYrCH-1er_GGwQOUUFtTQrmeLNACVOB8VvDgFkkJDLjUPZw8fKwwM1PBNJt-CVCQa4NOyBakDm3CZYoLpTArl7-Qr8N1GCM-f6PoJF_4-gpLsp2iBK2a_0VxcLaWkUkFn61FoOUt9DJpESjGJk./download [following]
# --2019-04-16 06:40:44--  https://public.boxcloud.com/d/1/b1!dw4qbcIkDnSN0U0uBWTdlBQVSTsQjQAnkq57cdovqB1aeTUZc07TyEPbxCMCQUkHpV0w6zBZY1RREAnZtds5s0t8sUzkppPlWcFYtQgkYwCr_BAA4DH6mRQAov3aK7mAbtuTAFRTPXzPcXM3adV9h2pI6Ki58K3Nn4ftUwEVB5UZXaM8b3IUb3Z-1PTmybIc5qlzsLxLRu3MGeIQdOj_g3QcsYyV3AxA0Iftw_Btj-MidgvoK7R4Vf-7twz4Ra_DQXqapo28DnjJr-zBE0PmwuqFq72B9bB7TPQOT06kU5BxU_qK3hIWYh_r2l6LiqCWJaCHjGR_-scyVrbwuL5pTGVZcuuYpTT88vCVyvleQITVosgetwVeBkfSJz3-6cjA6mTk0D9awcobJpc5uNKGnAntm725zkpZSm2trqWywR6g6wWCxAenM5CAYv0g3XcNXHVYnmTIzVHoAUo41NRgPL4wsNwCNAad79UpwpxKogFVDMQeE_MJEPayLQvXQMhFbgIRVdv2Gz1KPN-_e6Y9rxoDA0DE-svQs7WMvnVqNHrhbtlEKWsjuY4scC7wK0nwF2G4o_WOn-n4Y1oGmgbMNOu1dIgLcQ0q1Bv7QcH8fMko1Z9_uFtEFYahWlt5NEhkAWH-tkTZPPazh7mKVBf4q_X9JsyZeZfci_TbuZ5YOSjFtZ2gdxOx32GL1CxOBWWIBic2vjVv4yeNfCBjW47vJxy2Jgfa1eDE3Luub0FTtPyizEBx2emzk4srtXB8Y2b4bWCrRgcj28jdiQziXhwf54RKFbNsipuavekL6BCE1orwo4N3gtYJamlc5OH_hyHJNMGT-3yrx4fNLmahunfOFYDihGJ0_cDSGgBk_KlIR6_qQQgMD2Oc1VVtRjVhKiRQSnPmXnzg-9hgCksm_oS254d8i29Rq2KSMy6yvA8JNMUH89yIn5KZ-dnRANRw3ToAjcZqNbzcrAZMt01XLpGNOH3JNL2GzXV75x_mA9eR9hskSujf06QPU5U2VWF0MDh9VgaK0j590Q2C63Xt_kwx0UG7ltDhlywl5WvI_dfIC76QcxSfO7an6eVDy7guGPehShB4tg5ihst5ItWvMu0PA9J0JHA-NSDOTWRC-dXCa6OKGgqXxfoBLCjXirTbGem8KdNfzLGNTwbINgCr4MfS9wDwocn93-bO1K590LfTlrquqcKilYIClxoql97J3Pgp0k2er4mNqyTjeaP6BK3tZRYj94PRRPR1ULjADnYrCH-1er_GGwQOUUFtTQrmeLNACVOB8VvDgFkkJDLjUPZw8fKwwM1PBNJt-CVCQa4NOyBakDm3CZYoLpTArl7-Qr8N1GCM-f6PoJF_4-gpLsp2iBK2a_0VxcLaWkUkFn61FoOUt9DJpESjGJk./download
# Resolving public.boxcloud.com (public.boxcloud.com)... 107.152.27.200
# Connecting to public.boxcloud.com (public.boxcloud.com)|107.152.27.200|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2891 (2.8K) [text/csv]
# Saving to: ‘Geospatial_data.csv’
#
# 100%[======================================>] 2,891       --.-K/s   in 0s
#
# 2019-04-16 06:40:45 (151 MB/s) - ‘Geospatial_data.csv’ saved [2891/2891]

# %%
import numpy as np # library to handle data in a vectorized manner
import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import json # library to handle JSON files
# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library
import requests # library to handle requests
import random # library for random number generation
from IPython.display import Image 
from IPython.core.display import HTML
# Out:
# Fetching package metadata .............
# Solving package specifications: .
#
# # All requested packages already installed.
# # packages in environment at /opt/conda/envs/DSX-Python35:
# #
# geopy                     1.19.0                     py_0    conda-forge
# Fetching package metadata .............
# Solving package specifications: .
#
# # All requested packages already installed.
# # packages in environment at /opt/conda/envs/DSX-Python35:
# #
# folium                    0.5.0                      py_0    conda-forge

# %%
CLIENT_ID = 'YUKN0Q1PDQH3240RJVDFXOTHUVSJWX45FXKJLOFJJRWLQEMM' # your Foursquare ID
CLIENT_SECRET = '03BBZSSXV2FMQLDODD3FRPIT23H5UAXFKQTSODVJVT012EKQ' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 100
radius=500
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: YUKN0Q1PDQH3240RJVDFXOTHUVSJWX45FXKJLOFJJRWLQEMM
# CLIENT_SECRET:03BBZSSXV2FMQLDODD3FRPIT23H5UAXFKQTSODVJVT012EKQ

# %%
c=[]
for i in range(103):
    if data3["Borough"][i] != 'West Toronto':
         if data3["Borough"][i] != 'East Toronto':
            if data3["Borough"][i] != 'Central Toronto':
                if data3["Borough"][i] != 'Downtown Toronto':
                    c.append(i)
data4=data3.drop(c)
data4.reset_index(inplace=True)
data4=data4.drop(columns=["index"])

# %%
data4
# Out:
#    PostCode           Borough  \
# 0       M4E      East Toronto
# 1       M4K      East Toronto
# 2       M4L      East Toronto
# 3       M4M      East Toronto
# 4       M4N   Central Toronto
# 5       M4P   Central Toronto
# 6       M4R   Central Toronto
# 7       M4S   Central Toronto
# 8       M4T   Central Toronto
# 9       M4V   Central Toronto
# 10      M4W  Downtown Toronto
# 11      M4X  Downtown Toronto
# 12      M4Y  Downtown Toronto
# 13      M5A  Downtown Toronto
# 14      M5B  Downtown Toronto
# 15      M5C  Downtown Toronto
# 16      M5E  Downtown Toronto
# 17      M5G  Downtown Toronto
# 18      M5H  Downtown Toronto
# 19      M5J  Downtown Toronto
# 20      M5K  Downtown Toronto
# 21      M5L  Downtown Toronto
# 22      M5N   Central Toronto
# 23      M5P   Central Toronto
# 24      M5R   Central Toronto
# 25      M5S  Downtown Toronto
# 26      M5T  Downtown Toronto
# 27      M5V  Downtown Toronto
# 28      M5W  Downtown Toronto
# 29      M5X  Downtown Toronto
# 30      M6G  Downtown Toronto
# 31      M6H      West Toronto
# 32      M6J      West Toronto
# 33      M6K      West Toronto
# 34      M6P      West Toronto
# 35      M6R      West Toronto
# 36      M6S      West Toronto
# 37      M7Y      East Toronto
#
#                                         Neighbourhood   Latitude  Longitude
# 0                                         The Beaches  43.676357 -79.293031
# 1                         The Danforth West,Riverdale  43.679557 -79.352188
# 2                       The Beaches West,India Bazaar  43.668999 -79.315572
# 3                                     Studio District  43.659526 -79.340923
# 4                                       Lawrence Park  43.728020 -79.388790
# 5                                    Davisville North  43.712751 -79.390197
# 6                                  North Toronto West  43.715383 -79.405678
# 7                                          Davisville  43.704324 -79.388790
# 8                          Moore Park,Summerhill East  43.689574 -79.383160
# 9                            Deer Park,Forest Hill SE  43.686412 -79.400049
# 10                                           Rosedale  43.679563 -79.377529
# 11                         Cabbagetown,St. James Town  43.667967 -79.367675
# 12                               Church and Wellesley  43.665860 -79.383160
# 13                           Harbourfront,Regent Park  43.654260 -79.360636
# 14                            Ryerson,Garden District  43.657162 -79.378937
# 15                                     St. James Town  43.651494 -79.375418
# 16                                        Berczy Park  43.644771 -79.373306
# 17                                 Central Bay Street  43.657952 -79.387383
# 18                                      Adelaide,King  43.650571 -79.384568
# 19                  Harbourfront East,Toronto Islands  43.640816 -79.381752
# 20            Design Exchange,Toronto Dominion Centre  43.647177 -79.381576
# 21                      Commerce Court,Victoria Hotel  43.648198 -79.379817
# 22                                           Roselawn  43.711695 -79.416936
# 23                 Forest Hill North,Forest Hill West  43.696948 -79.411307
# 24                            The Annex,North Midtown  43.672710 -79.405678
# 25                      Harbord,University of Toronto  43.662696 -79.400049
# 26                              Chinatown,Grange Park  43.653206 -79.400049
# 27                             CN Tower,Bathurst Quay  43.628947 -79.394420
# 28                    Stn A PO Boxes 25 The Esplanade  43.646435 -79.374846
# 29              First Canadian Place,Underground city  43.648429 -79.382280
# 30                                           Christie  43.669542 -79.422564
# 31                        Dovercourt Village,Dufferin  43.669005 -79.442259
# 32                            Little Portugal,Trinity  43.647927 -79.419750
# 33                          Brockton,Exhibition Place  43.636847 -79.428191
# 34                       High Park,The Junction South  43.661608 -79.464763
# 35                              Parkdale,Roncesvalles  43.648960 -79.456325
# 36                                  Runnymede,Swansea  43.651571 -79.484450
# 37  Business Reply Mail Processing Centre 969 Eastern  43.662744 -79.321558

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
toronto_venues = getNearbyVenues(names=data4['Neighbourhood'],
                                   latitudes=data4['Latitude'],
                                   longitudes=data4['Longitude']
                                  )
# Out:
# The Beaches
# The Danforth West,Riverdale
# The Beaches West,India Bazaar
# Studio District
# Lawrence Park
# Davisville North
# North Toronto West
# Davisville
# Moore Park,Summerhill East
# Deer Park,Forest Hill SE
# Rosedale
# Cabbagetown,St. James Town
# Church and Wellesley
# Harbourfront,Regent Park
# Ryerson,Garden District
# St. James Town
# Berczy Park
# Central Bay Street
# Adelaide,King
# Harbourfront East,Toronto Islands
# Design Exchange,Toronto Dominion Centre
# Commerce Court,Victoria Hotel
# Roselawn
# Forest Hill North,Forest Hill West
# The Annex,North Midtown
# Harbord,University of Toronto
# Chinatown,Grange Park
# CN Tower,Bathurst Quay
# Stn A PO Boxes 25 The Esplanade
# First Canadian Place,Underground city
# Christie
# Dovercourt Village,Dufferin
# Little Portugal,Trinity
# Brockton,Exhibition Place
# High Park,The Junction South
# Parkdale,Roncesvalles
# Runnymede,Swansea
# Business Reply Mail Processing Centre 969 Eastern

# %%
print(toronto_venues.shape)
toronto_venues.head()
# Out:
# (1702, 7)
#                   Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0                  The Beaches              43.676357              -79.293031
# 1                  The Beaches              43.676357              -79.293031
# 2                  The Beaches              43.676357              -79.293031
# 3                  The Beaches              43.676357              -79.293031
# 4  The Danforth West,Riverdale              43.679557              -79.352188
#
#                                 Venue  Venue Latitude  Venue Longitude  \
# 0  The Big Carrot Natural Food Market       43.678879       -79.297734
# 1                 Grover Pub and Grub       43.679181       -79.297215
# 2                           Starbucks       43.678798       -79.298045
# 3                       Upper Beaches       43.680563       -79.292869
# 4                        Dolce Gelato       43.677773       -79.351187
#
#       Venue Category
# 0  Health Food Store
# 1                Pub
# 2        Coffee Shop
# 3       Neighborhood
# 4     Ice Cream Shop

# %%
toronto_venues.groupby('Neighborhood').count()
# Out:
#                                                    Neighborhood Latitude  \
# Neighborhood
# Adelaide,King                                                        100
# Berczy Park                                                           56
# Brockton,Exhibition Place                                             22
# Business Reply Mail Processing Centre 969 Eastern                     17
# CN Tower,Bathurst Quay                                                15
# Cabbagetown,St. James Town                                            48
# Central Bay Street                                                    86
# Chinatown,Grange Park                                                100
# Christie                                                              16
# Church and Wellesley                                                  89
# Commerce Court,Victoria Hotel                                        100
# Davisville                                                            34
# Davisville North                                                       9
# Deer Park,Forest Hill SE                                              14
# Design Exchange,Toronto Dominion Centre                              100
# Dovercourt Village,Dufferin                                           18
# First Canadian Place,Underground city                                100
# Forest Hill North,Forest Hill West                                     4
# Harbord,University of Toronto                                         34
# Harbourfront East,Toronto Islands                                    100
# Harbourfront,Regent Park                                              50
# High Park,The Junction South                                          24
# Lawrence Park                                                          3
# Little Portugal,Trinity                                               62
# Moore Park,Summerhill East                                             3
# North Toronto West                                                    20
# Parkdale,Roncesvalles                                                 16
# Rosedale                                                               4
# Roselawn                                                               1
# Runnymede,Swansea                                                     37
# Ryerson,Garden District                                              100
# St. James Town                                                       100
# Stn A PO Boxes 25 The Esplanade                                       96
# Studio District                                                       37
# The Annex,North Midtown                                               24
# The Beaches                                                            4
# The Beaches West,India Bazaar                                         16
# The Danforth West,Riverdale                                           43
#
#                                                    Neighborhood Longitude  \
# Neighborhood
# Adelaide,King                                                         100
# Berczy Park                                                            56
# Brockton,Exhibition Place                                              22
# Business Reply Mail Processing Centre 969 Eastern                      17
# CN Tower,Bathurst Quay                                                 15
# Cabbagetown,St. James Town                                             48
# Central Bay Street                                                     86
# Chinatown,Grange Park                                                 100
# Christie                                                               16
# Church and Wellesley                                                   89
# Commerce Court,Victoria Hotel                                         100
# Davisville                                                             34
# Davisville North                                                        9
# Deer Park,Forest Hill SE                                               14
# Design Exchange,Toronto Dominion Centre                               100
# Dovercourt Village,Dufferin                                            18
# First Canadian Place,Underground city                                 100
# Forest Hill North,Forest Hill West                                      4
# Harbord,University of Toronto                                          34
# Harbourfront East,Toronto Islands                                     100
# Harbourfront,Regent Park                                               50
# High Park,The Junction South                                           24
# Lawrence Park                                                           3
# Little Portugal,Trinity                                                62
# Moore Park,Summerhill East                                              3
# North Toronto West                                                     20
# Parkdale,Roncesvalles                                                  16
# Rosedale                                                                4
# Roselawn                                                                1
# Runnymede,Swansea                                                      37
# Ryerson,Garden District                                               100
# St. James Town                                                        100
# Stn A PO Boxes 25 The Esplanade                                        96
# Studio District                                                        37
# The Annex,North Midtown                                                24
# The Beaches                                                             4
# The Beaches West,India Bazaar                                          16
# The Danforth West,Riverdale                                            43
#
#                                                    Venue  Venue Latitude  \
# Neighborhood
# Adelaide,King                                        100             100
# Berczy Park                                           56              56
# Brockton,Exhibition Place                             22              22
# Business Reply Mail Processing Centre 969 Eastern     17              17
# CN Tower,Bathurst Quay                                15              15
# Cabbagetown,St. James Town                            48              48
# Central Bay Street                                    86              86
# Chinatown,Grange Park                                100             100
# Christie                                              16              16
# Church and Wellesley                                  89              89
# Commerce Court,Victoria Hotel                        100             100
# Davisville                                            34              34
# Davisville North                                       9               9
# Deer Park,Forest Hill SE                              14              14
# Design Exchange,Toronto Dominion Centre              100             100
# Dovercourt Village,Dufferin                           18              18
# First Canadian Place,Underground city                100             100
# Forest Hill North,Forest Hill West                     4               4
# Harbord,University of Toronto                         34              34
# Harbourfront East,Toronto Islands                    100             100
# Harbourfront,Regent Park                              50              50
# High Park,The Junction South                          24              24
# Lawrence Park                                          3               3
# Little Portugal,Trinity                               62              62
# Moore Park,Summerhill East                             3               3
# North Toronto West                                    20              20
# Parkdale,Roncesvalles                                 16              16
# Rosedale                                               4               4
# Roselawn                                               1               1
# Runnymede,Swansea                                     37              37
# Ryerson,Garden District                              100             100
# St. James Town                                       100             100
# Stn A PO Boxes 25 The Esplanade                       96              96
# Studio District                                       37              37
# The Annex,North Midtown                               24              24
# The Beaches                                            4               4
# The Beaches West,India Bazaar                         16              16
# The Danforth West,Riverdale                           43              43
#
#                                                    Venue Longitude  \
# Neighborhood
# Adelaide,King                                                  100
# Berczy Park                                                     56
# Brockton,Exhibition Place                                       22
# Business Reply Mail Processing Centre 969 Eastern               17
# CN Tower,Bathurst Quay                                          15
# Cabbagetown,St. James Town                                      48
# Central Bay Street                                              86
# Chinatown,Grange Park                                          100
# Christie                                                        16
# Church and Wellesley                                            89
# Commerce Court,Victoria Hotel                                  100
# Davisville                                                      34
# Davisville North                                                 9
# Deer Park,Forest Hill SE                                        14
# Design Exchange,Toronto Dominion Centre                        100
# Dovercourt Village,Dufferin                                     18
# First Canadian Place,Underground city                          100
# Forest Hill North,Forest Hill West                               4
# Harbord,University of Toronto                                   34
# Harbourfront East,Toronto Islands                              100
# Harbourfront,Regent Park                                        50
# High Park,The Junction South                                    24
# Lawrence Park                                                    3
# Little Portugal,Trinity                                         62
# Moore Park,Summerhill East                                       3
# North Toronto West                                              20
# Parkdale,Roncesvalles                                           16
# Rosedale                                                         4
# Roselawn                                                         1
# Runnymede,Swansea                                               37
# Ryerson,Garden District                                        100
# St. James Town                                                 100
# Stn A PO Boxes 25 The Esplanade                                 96
# Studio District                                                 37
# The Annex,North Midtown                                         24
# The Beaches                                                      4
# The Beaches West,India Bazaar                                   16
# The Danforth West,Riverdale                                     43
#
#                                                    Venue Category
# Neighborhood
# Adelaide,King                                                 100
# Berczy Park                                                    56
# Brockton,Exhibition Place                                      22
# Business Reply Mail Processing Centre 969 Eastern              17
# CN Tower,Bathurst Quay                                         15
# Cabbagetown,St. James Town                                     48
# Central Bay Street                                             86
# Chinatown,Grange Park                                         100
# Christie                                                       16
# Church and Wellesley                                           89
# Commerce Court,Victoria Hotel                                 100
# Davisville                                                     34
# Davisville North                                                9
# Deer Park,Forest Hill SE                                       14
# Design Exchange,Toronto Dominion Centre                       100
# Dovercourt Village,Dufferin                                    18
# First Canadian Place,Underground city                         100
# Forest Hill North,Forest Hill West                              4
# Harbord,University of Toronto                                  34
# Harbourfront East,Toronto Islands                             100
# Harbourfront,Regent Park                                       50
# High Park,The Junction South                                   24
# Lawrence Park                                                   3
# Little Portugal,Trinity                                        62
# Moore Park,Summerhill East                                      3
# North Toronto West                                             20
# Parkdale,Roncesvalles                                          16
# Rosedale                                                        4
# Roselawn                                                        1
# Runnymede,Swansea                                              37
# Ryerson,Garden District                                       100
# St. James Town                                                100
# Stn A PO Boxes 25 The Esplanade                                96
# Studio District                                                37
# The Annex,North Midtown                                        24
# The Beaches                                                     4
# The Beaches West,India Bazaar                                  16
# The Danforth West,Riverdale                                    43

# %%
print('There are {} uniques categories.'.format(len(toronto_venues['Venue Category'].unique())))
# Out:
# There are 233 uniques categories.

# %%
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")
toronto_onehot['Neighborhood'] = toronto_venues['Neighborhood'] 
fixed_columns = [toronto_onehot.columns[-1]] + list(toronto_onehot.columns[:-1])
toronto_onehot = toronto_onehot[fixed_columns]
toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()

# %%
num_top_venues = 5

for hood in toronto_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = toronto_grouped[toronto_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Adelaide,King----
#                  venue  freq
# 0          Coffee Shop  0.06
# 1      Thai Restaurant  0.04
# 2                 Café  0.04
# 3           Steakhouse  0.04
# 4  American Restaurant  0.04
#
#
# ----Berczy Park----
#           venue  freq
# 0   Coffee Shop  0.09
# 1  Cocktail Bar  0.05
# 2    Steakhouse  0.04
# 3          Café  0.04
# 4   Cheese Shop  0.04
#
#
# ----Brockton,Exhibition Place----
#                 venue  freq
# 0      Breakfast Spot  0.09
# 1                Café  0.09
# 2         Coffee Shop  0.09
# 3         Yoga Studio  0.05
# 4  Italian Restaurant  0.05
#
#
# ----Business Reply Mail Processing Centre 969 Eastern----
#                 venue  freq
# 0  Light Rail Station  0.12
# 1         Yoga Studio  0.06
# 2       Auto Workshop  0.06
# 3         Pizza Place  0.06
# 4          Comic Shop  0.06
#
#
# ----CN Tower,Bathurst Quay----
#               venue  freq
# 0   Airport Service  0.20
# 1    Airport Lounge  0.13
# 2  Airport Terminal  0.13
# 3     Boat or Ferry  0.07
# 4  Sculpture Garden  0.07
#
#
# ----Cabbagetown,St. James Town----
#          venue  freq
# 0  Coffee Shop  0.10
# 1   Restaurant  0.06
# 2         Park  0.06
# 3         Café  0.06
# 4       Bakery  0.04
#
#
# ----Central Bay Street----
#                 venue  freq
# 0         Coffee Shop  0.15
# 1  Italian Restaurant  0.05
# 2                Café  0.03
# 3      Ice Cream Shop  0.03
# 4        Burger Joint  0.03
#
#
# ----Chinatown,Grange Park----
#                            venue  freq
# 0                           Café  0.08
# 1  Vegetarian / Vegan Restaurant  0.06
# 2                            Bar  0.06
# 3          Vietnamese Restaurant  0.04
# 4             Mexican Restaurant  0.04
#
#
# ----Christie----
#                 venue  freq
# 0                Café  0.19
# 1       Grocery Store  0.19
# 2                Park  0.12
# 3   Convenience Store  0.06
# 4  Italian Restaurant  0.06
#
#
# ----Church and Wellesley----
#                  venue  freq
# 0  Japanese Restaurant  0.07
# 1          Coffee Shop  0.07
# 2     Sushi Restaurant  0.04
# 3              Gay Bar  0.04
# 4         Burger Joint  0.03
#
#
# ----Commerce Court,Victoria Hotel----
#                  venue  freq
# 0          Coffee Shop  0.13
# 1                 Café  0.06
# 2                Hotel  0.06
# 3  American Restaurant  0.04
# 4           Restaurant  0.04
#
#
# ----Davisville----
#               venue  freq
# 0    Sandwich Place  0.09
# 1      Dessert Shop  0.09
# 2  Sushi Restaurant  0.06
# 3              Café  0.06
# 4       Pizza Place  0.06
#
#
# ----Davisville North----
#             venue  freq
# 0      Restaurant  0.11
# 1           Hotel  0.11
# 2  Sandwich Place  0.11
# 3    Burger Joint  0.11
# 4  Clothing Store  0.11
#
#
# ----Deer Park,Forest Hill SE----
#                  venue  freq
# 0                  Pub  0.14
# 1          Coffee Shop  0.14
# 2    Convenience Store  0.07
# 3  American Restaurant  0.07
# 4          Supermarket  0.07
#
#
# ----Design Exchange,Toronto Dominion Centre----
#                  venue  freq
# 0          Coffee Shop  0.12
# 1                 Café  0.08
# 2                Hotel  0.07
# 3           Restaurant  0.05
# 4  American Restaurant  0.04
#
#
# ----Dovercourt Village,Dufferin----
#          venue  freq
# 0  Supermarket  0.11
# 1       Bakery  0.11
# 2     Pharmacy  0.11
# 3         Café  0.06
# 4         Bank  0.06
#
#
# ----First Canadian Place,Underground city----
#                 venue  freq
# 0         Coffee Shop  0.09
# 1                Café  0.07
# 2               Hotel  0.06
# 3          Restaurant  0.05
# 4  Seafood Restaurant  0.03
#
#
# ----Forest Hill North,Forest Hill West----
#                 venue  freq
# 0               Trail  0.25
# 1  Mexican Restaurant  0.25
# 2    Sushi Restaurant  0.25
# 3       Jewelry Store  0.25
# 4         Yoga Studio  0.00
#
#
# ----Harbord,University of Toronto----
#                  venue  freq
# 0                 Café  0.18
# 1            Bookstore  0.06
# 2           Restaurant  0.06
# 3                  Bar  0.06
# 4  Japanese Restaurant  0.06
#
#
# ----Harbourfront East,Toronto Islands----
#                 venue  freq
# 0         Coffee Shop  0.13
# 1            Aquarium  0.05
# 2               Hotel  0.05
# 3                Café  0.04
# 4  Italian Restaurant  0.04
#
#
# ----Harbourfront,Regent Park----
#          venue  freq
# 0  Coffee Shop  0.18
# 1       Bakery  0.06
# 2         Café  0.06
# 3         Park  0.06
# 4          Pub  0.06
#
#
# ----High Park,The Junction South----
#                  venue  freq
# 0   Mexican Restaurant  0.08
# 1                 Café  0.08
# 2                  Bar  0.08
# 3            Bookstore  0.04
# 4  Arts & Crafts Store  0.04
#
#
# ----Lawrence Park----
#            venue  freq
# 0           Park  0.33
# 1    Swim School  0.33
# 2       Bus Line  0.33
# 3    Yoga Studio  0.00
# 4  Movie Theater  0.00
#
#
# ----Little Portugal,Trinity----
#                      venue  freq
# 0                      Bar  0.13
# 1         Asian Restaurant  0.05
# 2              Coffee Shop  0.05
# 3  New American Restaurant  0.03
# 4              Men's Store  0.03
#
#
# ----Moore Park,Summerhill East----
#             venue  freq
# 0      Restaurant  0.33
# 1             Gym  0.33
# 2      Playground  0.33
# 3     Music Store  0.00
# 4  Massage Studio  0.00
#
#
# ----North Toronto West----
#                  venue  freq
# 0       Clothing Store  0.20
# 1          Coffee Shop  0.10
# 2  Sporting Goods Shop  0.10
# 3         Dessert Shop  0.05
# 4   Salon / Barbershop  0.05
#
#
# ----Parkdale,Roncesvalles----
#                 venue  freq
# 0      Breakfast Spot  0.12
# 1           Gift Shop  0.12
# 2           Bookstore  0.06
# 3  Italian Restaurant  0.06
# 4                Bank  0.06
#
#
# ----Rosedale----
#            venue  freq
# 0           Park  0.50
# 1     Playground  0.25
# 2          Trail  0.25
# 3    Yoga Studio  0.00
# 4  Movie Theater  0.00
#
#
# ----Roselawn----
#                       venue  freq
# 0                    Garden   1.0
# 1               Yoga Studio   0.0
# 2            Massage Studio   0.0
# 3  Mediterranean Restaurant   0.0
# 4               Men's Store   0.0
#
#
# ----Runnymede,Swansea----
#                 venue  freq
# 0         Coffee Shop  0.11
# 1         Pizza Place  0.08
# 2                Café  0.08
# 3  Italian Restaurant  0.05
# 4    Sushi Restaurant  0.05
#
#
# ----Ryerson,Garden District----
#                        venue  freq
# 0                Coffee Shop  0.08
# 1             Clothing Store  0.07
# 2                       Café  0.04
# 3             Cosmetics Shop  0.03
# 4  Middle Eastern Restaurant  0.03
#
#
# ----St. James Town----
#             venue  freq
# 0     Coffee Shop  0.08
# 1            Café  0.05
# 2           Hotel  0.05
# 3      Restaurant  0.05
# 4  Cosmetics Shop  0.04
#
#
# ----Stn A PO Boxes 25 The Esplanade----
#          venue  freq
# 0  Coffee Shop  0.11
# 1   Restaurant  0.04
# 2         Café  0.04
# 3        Hotel  0.03
# 4          Pub  0.03
#
#
# ----Studio District----
#                 venue  freq
# 0                Café  0.11
# 1         Coffee Shop  0.08
# 2  Italian Restaurant  0.05
# 3              Bakery  0.05
# 4           Gastropub  0.05
#
#
# ----The Annex,North Midtown----
#             venue  freq
# 0     Coffee Shop  0.12
# 1  Sandwich Place  0.12
# 2            Café  0.12
# 3     Pizza Place  0.08
# 4  History Museum  0.04
#
#
# ----The Beaches----
#                       venue  freq
# 0         Health Food Store  0.25
# 1               Coffee Shop  0.25
# 2                       Pub  0.25
# 3               Music Store  0.00
# 4  Mediterranean Restaurant  0.00
#
#
# ----The Beaches West,India Bazaar----
#                 venue  freq
# 0       Movie Theater  0.06
# 1  Italian Restaurant  0.06
# 2             Brewery  0.06
# 3   Fish & Chips Shop  0.06
# 4           Pet Store  0.06
#
#
# ----The Danforth West,Riverdale----
#                 venue  freq
# 0    Greek Restaurant  0.19
# 1         Coffee Shop  0.09
# 2  Italian Restaurant  0.07
# 3      Ice Cream Shop  0.07
# 4           Bookstore  0.05

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = toronto_grouped['Neighborhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#                                         Neighborhood 1st Most Common Venue  \
# 0                                      Adelaide,King           Coffee Shop
# 1                                        Berczy Park           Coffee Shop
# 2                          Brockton,Exhibition Place           Coffee Shop
# 3  Business Reply Mail Processing Centre 969 Eastern    Light Rail Station
# 4                             CN Tower,Bathurst Quay       Airport Service
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0       Thai Restaurant                  Café            Steakhouse
# 1          Cocktail Bar                   Pub           Cheese Shop
# 2        Breakfast Spot                  Café           Yoga Studio
# 3           Yoga Studio         Garden Center         Auto Workshop
# 4        Airport Lounge      Airport Terminal       Harbor / Marina
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0   American Restaurant      Asian Restaurant            Restaurant
# 1    Seafood Restaurant            Steakhouse        Farmers Market
# 2         Burrito Place            Restaurant  Caribbean Restaurant
# 3            Restaurant  Fast Food Restaurant        Farmers Market
# 4              Boutique                 Plane      Sculpture Garden
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0                 Hotel                   Bar                 Bakery
# 1            Restaurant                  Café                 Bakery
# 2          Climbing Gym             Pet Store                Stadium
# 3                   Spa         Burrito Place                 Garden
# 4          Airport Gate    Airport Food Court                Airport

# %%
neighborhoods_venues_sorted.head()
# Out:
#    Cluster Labels                                       Neighborhood  \
# 0               1                                      Adelaide,King
# 1               1                                        Berczy Park
# 2               1                          Brockton,Exhibition Place
# 3               1  Business Reply Mail Processing Centre 969 Eastern
# 4               1                             CN Tower,Bathurst Quay
#
#   1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 0           Coffee Shop       Thai Restaurant                  Café
# 1           Coffee Shop          Cocktail Bar                   Pub
# 2           Coffee Shop        Breakfast Spot                  Café
# 3    Light Rail Station           Yoga Studio         Garden Center
# 4       Airport Service        Airport Lounge      Airport Terminal
#
#   4th Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 0            Steakhouse   American Restaurant      Asian Restaurant
# 1           Cheese Shop    Seafood Restaurant            Steakhouse
# 2           Yoga Studio         Burrito Place            Restaurant
# 3         Auto Workshop            Restaurant  Fast Food Restaurant
# 4       Harbor / Marina              Boutique                 Plane
#
#   7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 0            Restaurant                 Hotel                   Bar
# 1        Farmers Market            Restaurant                  Café
# 2  Caribbean Restaurant          Climbing Gym             Pet Store
# 3        Farmers Market                   Spa         Burrito Place
# 4      Sculpture Garden          Airport Gate    Airport Food Court
#
#   10th Most Common Venue
# 0                 Bakery
# 1                 Bakery
# 2                Stadium
# 3                 Garden
# 4                Airport

# %%
# set number of clusters
kclusters = 4

toronto_grouped_clustering = toronto_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_
# Out:
# array([3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 0,
#        3, 2, 3, 3, 0, 1, 3, 3, 3, 3, 3, 3, 3, 3, 3], dtype=int32)

# %%
# add clustering labels
neighborhoods_venues_sorted=neighborhoods_venues_sorted.drop(columns=["Cluster Labels"])
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

toronto_merged = data4

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
toronto_merged = toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighbourhood')

toronto_merged.head() # check the last columns!
# Out:
#   PostCode          Borough                  Neighbourhood   Latitude  \
# 0      M4E     East Toronto                    The Beaches  43.676357
# 1      M4K     East Toronto    The Danforth West,Riverdale  43.679557
# 2      M4L     East Toronto  The Beaches West,India Bazaar  43.668999
# 3      M4M     East Toronto                Studio District  43.659526
# 4      M4N  Central Toronto                  Lawrence Park  43.728020
#
#    Longitude  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 0 -79.293031               3           Coffee Shop     Health Food Store
# 1 -79.352188               3      Greek Restaurant           Coffee Shop
# 2 -79.315572               3                   Pub    Italian Restaurant
# 3 -79.340923               3                  Café           Coffee Shop
# 4 -79.388790               0                  Park           Swim School
#
#   3rd Most Common Venue    4th Most Common Venue 5th Most Common Venue  \
# 0                   Pub              Wings Joint          Dessert Shop
# 1    Italian Restaurant           Ice Cream Shop             Bookstore
# 2         Burrito Place        Fish & Chips Shop          Burger Joint
# 3    Italian Restaurant                   Bakery             Gastropub
# 4              Bus Line  Comfort Food Restaurant    Dim Sum Restaurant
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0           Event Space  Ethiopian Restaurant     Electronics Store
# 1   Japanese Restaurant  Caribbean Restaurant                Bakery
# 2  Fast Food Restaurant         Movie Theater            Steakhouse
# 3   American Restaurant                  Bank                   Bar
# 4           Event Space  Ethiopian Restaurant     Electronics Store
#
#          9th Most Common Venue 10th Most Common Venue
# 0  Eastern European Restaurant    Dumpling Restaurant
# 1                   Sports Bar                    Spa
# 2                      Brewery              Pet Store
# 3                  Fish Market              Bookstore
# 4  Eastern European Restaurant    Dumpling Restaurant

# %%
# create map
map_clusters = folium.Map(location=[43.728, -79.3888], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighbourhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
